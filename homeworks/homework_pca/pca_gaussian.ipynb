# %%
import Pkg
Pkg.activate(".")
# Out:
#   Activating project at `~/Documents/programming/BME-574-2024`

# %%
Pkg.instantiate()
# Out:
# Precompiling project...
#   ✓ CustomUnitRanges
#   ✓ LittleCMS_jll
#   ✓ IntegralArrays
#   ✓ Ghostscript_jll
#   ✓ RegionTrees
#   ✓ CoordinateTransformations
#   ✓ CatIndices
#   ✓ FFTViews
#   ✓ Rotations
#   ✓ StaticArrayInterface
#   ✓ OpenJpeg_jll
#   ✓ ColorVectorSpace
#   ✓ Rotations → RotationsRecipesBaseExt
#   ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#   ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#   ✓ CloseOpenIntervals
#   ✓ ImageMagick_jll
#   ✓ LayoutPointers
#   ✓ TiledIteration
#   ✓ ColorSchemes
#   ✓ Polynomials
#   ✓ VectorizationBase
#   ✓ Polynomials → PolynomialsChainRulesCoreExt
#   ✓ Polynomials → PolynomialsMutableArithmeticsExt
#   ✓ SLEEFPirates
#   ✓ PlotUtils
#   ✓ PlotThemes
#   ✓ RecipesPipeline
#   ✓ JLD2
#   ✓ ImageCore
#   ✓ MetaGraphs
#   ✓ JpegTurbo
#   ✓ Sixel
#   ✓ ImageBase
#   ✓ ImageMagick
#   ✓ PNGFiles
#   ✓ HistogramThresholding
#   ✓ ImageShow
#   ✓ ImageAxes
#   ✓ ImageTransformations
#   ✓ LoopVectorization
#   ✓ ImageBinarization
#   ✓ ImageMetadata
#   ✓ LoopVectorization → SpecialFunctionsExt
#   ✓ LoopVectorization → ForwardDiffExt
#   ✓ ImageContrastAdjustment
#   ✓ Netpbm
#   ✓ ImageMorphology
#   ✓ ImageDistances
#   ✓ Plots
#   ✓ Plots → UnitfulExt
#   ✓ Plots → FileIOExt
#   ✓ ImageFiltering
#   ✓ ImageSegmentation
#   ✓ ImageCorners
#   ✓ ImageQualityIndexes
#   ✓ Images
#   57 dependencies successfully precompiled in 45 seconds. 314 already precompiled.

# %%
using Distributions, Random, LinearAlgebra, Plots
# Out:
# [ Info: Precompiling IJuliaExt [2f4121a4-3b3a-5ce6-9c5e-1f2673ce168a]

# %%
nd = Normal(0,1)
# Out:
# Normal{Float64}(μ=0.0, σ=1.0)

# %%
data = rand(nd,(1000,2))
# Out:
# 1000×2 Matrix{Float64}:
#   1.15714    -0.593756
#  -0.652487    0.311072
#   1.24772    -1.16964
#  -0.394913    0.326471
#  -0.306613    0.0655445
#  -0.616052   -1.29607
#  -1.52722     1.1387
#  -0.327895    1.07163
#   0.202205    1.45327
#  -0.108574    1.71115
#   0.776812   -0.681824
#   0.0932655  -1.09527
#  -0.856573    0.186701
#   ⋮
#  -0.528049    0.266447
#  -0.10821    -1.02729
#  -2.11617    -0.401182
#  -1.51722     1.63227
#  -1.39989    -1.25115
#   0.0401765  -1.26038
#   0.182804   -0.122409
#   0.703569   -2.74066
#  -2.09155    -0.851849
#   1.09019     0.268761
#   0.391156   -1.49333
#  -1.89881     0.524975

# %%
scatter(data[:,1],data[:,2], aspect_ratio = :equal, legend = nothing )

# %%
data[1,:]
# Out:
# 2-element Vector{Float64}:
#  0.4982769193274042
#  0.2730143958127022

# %%
datas = copy(data)
datas[:,2] = datas[:,2]*3
# Out:
# 1000-element Vector{Float64}:
#  -1.7812681371196741
#   0.9332151209700374
#  -3.50892582179244
#   0.97941314197891
#   0.19663339766869592
#  -3.8882108541642015
#   3.4161009843549777
#   3.2148983589645788
#   4.359803078640002
#   5.133452995379377
#  -2.0454725349691456
#  -3.285817330227137
#   0.560102534299538
#   ⋮
#   0.7993416579110726
#  -3.0818556611457755
#  -1.2035459297648978
#   4.896815300212115
#  -3.753453300383816
#  -3.7811435277922314
#  -0.36722752632804323
#  -8.22198622219695
#  -2.555547294629342
#   0.8062844985974336
#  -4.479980728234931
#   1.5749240059474596

# %%
scatter(datas[:,1],datas[:,2], aspect_ratio = :equal, legend = nothing )

# %%
θ = π/4
# Out:
# 0.7853981633974483

# %%
r = [[cos(θ), -sin(θ)] [sin(θ), cos(θ)]]
# Out:
# 2×2 Matrix{Float64}:
#   0.707107  0.707107
#  -0.707107  0.707107

# %%
datar = datas * r
# Out:
# 1000×2 Matrix{Float64}:
#   2.07777   -0.441328
#  -1.12126    0.198505
#   3.36346   -1.59891
#  -0.971795   0.413304
#  -0.355849  -0.0777674
#   2.31377   -3.185
#  -3.49546    1.33564
#  -2.50513    2.04142
#  -2.93987    3.22583
#  -3.70667    3.55313
#   1.99566   -0.897078
#   2.38937   -2.25748
#  -1.00174   -0.209636
#   ⋮
#  -0.938607   0.191833
#   2.10269   -2.25572
#  -0.64532   -2.34739
#  -4.53541    2.38974
#   1.66422   -3.64397
#   2.70208   -2.64526
#   0.388931  -0.130407
#   6.31132   -5.31632
#   0.328097  -3.28599
#   0.200754   1.34101
#   3.44441   -2.89124
#  -2.4563    -0.22902

# %%
scatter(datar[:,1],datar[:,2], aspect_ratio = :equal, legend = nothing )

# %%
u,s,v = svd(datar/sqrt(1000))
# Out:
# SVD{Float64, Float64, Matrix{Float64}, Vector{Float64}}
# U factor:
# 1000×2 Matrix{Float64}:
#  -0.018213     0.0367945
#   0.00953637  -0.0207219
#  -0.0360011    0.0402503
#   0.0100431   -0.012692
#   0.00198916  -0.00964992
#  -0.0401313   -0.0178374
#   0.0350114   -0.0489482
#   0.0330818   -0.011408
#   0.0449404    0.00473782
#   0.0528736   -0.00525125
#  -0.0209804    0.0250088
#  -0.0338405    0.00410378
#   0.00566806  -0.0269625
#   ⋮
#   0.00817202  -0.0167859
#  -0.0317633   -0.00226425
#  -0.0126521   -0.0656738
#   0.0502675   -0.0491721
#  -0.0388366   -0.0423736
#  -0.0389499    0.00262467
#  -0.00376147   0.00584388
#  -0.0846217    0.0249578
#  -0.026578    -0.064415
#   0.00843684   0.033766
#  -0.0461076    0.0138425
#   0.0159986   -0.0598898
# singular values:
# 2-element Vector{Float64}:
#  3.0692665479898116
#  1.0121738701038565
# Vt factor:
# 2×2 Matrix{Float64}:
#  -0.698862  0.715257
#   0.715257  0.698862

# %%
v * r
# Out:
# 2×2 Matrix{Float64}:
#  -0.999933   0.0115933
#   0.0115933  0.999933
